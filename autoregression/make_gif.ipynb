# %%
import autoregression
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
autoregression.compare_predictions(iris,'sepal length')
# Out:
# MAKE SUBSAMPLE TIME: 4.0531158447265625e-06
# CLEAN_DF TIME: 0.1845109462738037
# PLOT CORRELATION TIME: 0.3068118095397949
# MAKE SCATTER TIME: 1.429060697555542
#
# DF COLUMNS:
# ['sepal_width', 'petal_length', 'petal_width', 'species', 'sepal_length']
#
# DF COLUMNS AFTER TRANSFORM:
# ['sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species_setosa_category', 'species_versicolor_category', 'species_virginica_category', 'sepal_length']
#
# 35
# Y VARIABLE: "sepal_length" IS CONTINUOUS
#
# ['sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species_setosa_category', 'species_versicolor_category', 'species_virginica_category', 'sepal_length']
# 0it [00:00, ?it/s]/Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# 13it [00:09,  1.38it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# RR: mean=-0.100971 std=0.043714
# CV CALC TIME: 0.03431200981140137
# PLOT PREDICTED VS ACTUALS TIME: 0.23425579071044922
# PLOT COEFFICIANTS TIME: 0.41902995109558105
# PLOT BOOTSTRAP COEFFICIANTS TIME: 3.1946940422058105
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.8035519123077393
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.004829883575439453
# PLOT PREDICTEDS_VS_ACTUALS TIME: 3.7628378868103027
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:356: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  17%|█▋        | 1/6 [00:10<00:50, 10.03s/it]
# PLOT RESIDUAL ERROR TIME: 0.5364329814910889
# RR: MSE = 0.0926278995127196
# LASSO: mean=-0.101770 std=0.037576
# CV CALC TIME: 0.09681010246276855
# PLOT PREDICTED VS ACTUALS TIME: 0.2260732650756836
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# PLOT COEFFICIANTS TIME: 0.34929633140563965
# PLOT BOOTSTRAP COEFFICIANTS TIME: 2.9711811542510986
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.5866951942443848
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0015158653259277344
# PLOT PREDICTEDS_VS_ACTUALS TIME: 2.917820930480957
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:356: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  33%|███▎      | 2/6 [00:18<00:37,  9.25s/it]
# PLOT RESIDUAL ERROR TIME: 0.19625091552734375
# LASSO: MSE = 0.0895686483281032
# DT: mean=-0.172767 std=0.058700
# CV CALC TIME: 0.025961875915527344
# PLOT PREDICTED VS ACTUALS TIME: 0.22777915000915527
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.7517876625061035
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0015707015991210938
# PLOT PREDICTEDS_VS_ACTUALS TIME: 2.8527591228485107
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:356: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  50%|█████     | 3/6 [00:23<00:23,  7.86s/it]
# PLOT RESIDUAL ERROR TIME: 0.18801212310791016
# DT: MSE = 0.07315555555555561
# RF: mean=-0.121515 std=0.032006
# CV CALC TIME: 0.1811668872833252
# PLOT PREDICTED VS ACTUALS TIME: 0.24608635902404785
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.6103920936584473
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0015459060668945312
# PLOT PREDICTEDS_VS_ACTUALS TIME: 2.8529410362243652
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:356: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  67%|██████▋   | 4/6 [00:28<00:14,  7.21s/it]
# PLOT RESIDUAL ERROR TIME: 0.18518304824829102
# RF: MSE = 0.07003715716483011
# GB: mean=-0.117490 std=0.038596
# CV CALC TIME: 0.30873990058898926
# PLOT PREDICTED VS ACTUALS TIME: 0.22561883926391602
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.5455198287963867
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0026366710662841797
# PLOT PREDICTEDS_VS_ACTUALS TIME: 2.6619157791137695
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:356: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  83%|████████▎ | 5/6 [00:34<00:06,  6.85s/it]
# PLOT RESIDUAL ERROR TIME: 0.3315742015838623
# GB: MSE = 0.06528721630435254
# GB: mean=-0.119942 std=0.037522
# CV CALC TIME: 0.6341018676757812
# PLOT PREDICTED VS ACTUALS TIME: 0.25076723098754883
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.675896167755127
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0018701553344726562
# PLOT PREDICTEDS_VS_ACTUALS TIME: 2.705751657485962
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:356: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
# 100%|██████████| 6/6 [00:40<00:00,  6.74s/it]
# PLOT RESIDUAL ERROR TIME: 0.18645024299621582
# GB: MSE = 0.07933224451936735
# PLOT BAR AND VIOLIN TIME: 1.8165647983551025
# (['RR', 'LASSO', 'DT', 'RF', 'GB', 'GB'],
#  [array([-0.06922269, -0.05374298, -0.07089901, -0.11045051, -0.12201605,
#          -0.14353475, -0.10857675, -0.06553661, -0.0647706 , -0.20096333]),
#   array([-0.07466373, -0.05449891, -0.06518851, -0.13789174, -0.11809095,
#          -0.14366524, -0.10407609, -0.08143108, -0.06681544, -0.17137648]),
#   array([-0.09      , -0.14233333, -0.18733333, -0.24733333, -0.11866667,
#          -0.178     , -0.20333333, -0.28133333, -0.10066667, -0.17866667]),
#   array([-0.09588667, -0.10006   , -0.0918    , -0.14070043, -0.16433333,
#          -0.14448   , -0.11858027, -0.16766   , -0.12789333, -0.06375333]),
#   array([-0.05917531, -0.07240266, -0.08142698, -0.1216504 , -0.15951176,
#          -0.16935599, -0.1281116 , -0.17276813, -0.09473567, -0.11575913]),
#   array([-0.06726785, -0.07437928, -0.08250389, -0.18768767, -0.14273887,
#          -0.16258397, -0.14544409, -0.11835523, -0.11215202, -0.10631074])],
#  [RidgeCV(alphas=array([  1.00000e-02,   5.62341e-01,   3.16228e+01,   1.77828e+03,
#            1.00000e+05]),
#       cv=None, fit_intercept=True, gcv_mode=None, normalize=False,
#       scoring=None, store_cv_values=False),
#   LassoCV(alphas=array([  1.00000e-02,   5.62341e-01,   3.16228e+01,   1.77828e+03,
#            1.00000e+05]),
#       copy_X=True, cv=None, eps=0.001, fit_intercept=True, max_iter=1000,
#       n_alphas=100, n_jobs=1, normalize=False, positive=False,
#       precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#       verbose=False),
#   DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              presort=False, random_state=None, splitter='best'),
#   RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0, warm_start=False),
#   GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#                max_leaf_nodes=None, min_impurity_decrease=0.0,
#                min_impurity_split=None, min_samples_leaf=1,
#                min_samples_split=2, min_weight_fraction_leaf=0.0,
#                n_estimators=100, presort='auto', random_state=None,
#                subsample=1.0, verbose=0, warm_start=False),
#   AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#            n_estimators=50, random_state=None)],
#  <regression_tools.dftransformers.FeatureUnion at 0x11dc79668>)

# %%
2 * '3'
