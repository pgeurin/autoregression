# %%
import autoregression
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
autoregression.compare_predictions(iris,'sepal length')
# Out:
# MAKE SUBSAMPLE TIME: 3.0994415283203125e-06
# CLEAN_DF TIME: 0.30732011795043945
# PLOT CORRELATION TIME: 0.10704302787780762
# MAKE SCATTER TIME: 1.4254801273345947
#
# DF COLUMNS:
# ['sepal_width', 'petal_length', 'petal_width', 'species', 'sepal_length']
#
# DF COLUMNS AFTER TRANSFORM:
# ['sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species_setosa_category', 'species_versicolor_category', 'species_virginica_category', 'sepal_length']
#
# 35
# Y VARIABLE: "sepal_length" IS CONTINUOUS
#
# ['sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species_setosa_category', 'species_versicolor_category', 'species_virginica_category', 'sepal_length']
# 0it [00:00, ?it/s]
# 1it [00:00,  1.21it/s]
# 2it [00:01,  1.27it/s]
# 3it [00:02,  1.36it/s]
# 4it [00:02,  1.39it/s]
# 5it [00:03,  1.41it/s]
# 6it [00:04,  1.43it/s]
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/Users/macbookpro/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Users/macbookpro/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py", line 148, in run
#     for instance in self.tqdm_cls._instances:
#   File "/Users/macbookpro/anaconda3/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#
# 13it [00:08,  1.46it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# RR: mean=-0.100971 std=0.043714
# CV CALC TIME: 0.029477834701538086
# PLOT PREDICTED VS ACTUALS TIME: 0.22232699394226074
# PLOT COEFFICIANTS TIME: 0.3176100254058838
# PLOT BOOTSTRAP COEFFICIANTS TIME: 3.0423789024353027
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.5280158519744873
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.002187013626098633
# PLOT PREDICTEDS_VS_ACTUALS TIME: 2.808058977127075
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  17%|█▋        | 1/6 [00:08<00:40,  8.18s/it]
# PLOT RESIDUAL ERROR TIME: 0.18764376640319824
# RR: MSE = 0.08894960498983975
# LASSO: mean=-0.101770 std=0.037576
# CV CALC TIME: 0.10657095909118652
# PLOT PREDICTED VS ACTUALS TIME: 0.23151111602783203
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# PLOT COEFFICIANTS TIME: 0.31603288650512695
# PLOT BOOTSTRAP COEFFICIANTS TIME: 2.9023220539093018
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.479902982711792
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0017850399017333984
# PLOT PREDICTEDS_VS_ACTUALS TIME: 2.509242057800293
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  33%|███▎      | 2/6 [00:16<00:32,  8.02s/it]
# PLOT RESIDUAL ERROR TIME: 0.18507695198059082
# LASSO: MSE = 0.09985365253676359
# DT: mean=-0.176700 std=0.046903
# CV CALC TIME: 0.025339126586914062
# PLOT PREDICTED VS ACTUALS TIME: 0.4274601936340332
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.4666380882263184
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0014977455139160156
# PLOT PREDICTEDS_VS_ACTUALS TIME: 2.6197619438171387
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  50%|█████     | 3/6 [00:20<00:20,  6.94s/it]
# PLOT RESIDUAL ERROR TIME: 0.20430207252502441
# DT: MSE = 0.056933333333333315
# RF: mean=-0.116020 std=0.029206
# CV CALC TIME: 0.19232821464538574
# PLOT PREDICTED VS ACTUALS TIME: 0.23863911628723145
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.5695810317993164
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0015039443969726562
# PLOT PREDICTEDS_VS_ACTUALS TIME: 2.732494831085205
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  67%|██████▋   | 4/6 [00:25<00:12,  6.48s/it]
# PLOT RESIDUAL ERROR TIME: 0.1820380687713623
# RF: MSE = 0.06460818862251917
# GB: mean=-0.117713 std=0.038305
# CV CALC TIME: 0.2879939079284668
# PLOT PREDICTED VS ACTUALS TIME: 0.24854397773742676
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.4960048198699951
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0028388500213623047
# PLOT PREDICTEDS_VS_ACTUALS TIME: 2.8103630542755127
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  83%|████████▎ | 5/6 [00:31<00:06,  6.25s/it]
# PLOT RESIDUAL ERROR TIME: 0.17525076866149902
# GB: MSE = 0.058680045022647356
# GB: mean=-0.116075 std=0.025627
# CV CALC TIME: 0.6698508262634277
# PLOT PREDICTED VS ACTUALS TIME: 0.23195815086364746
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.558823823928833
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0016398429870605469
# PLOT PREDICTEDS_VS_ACTUALS TIME: 2.492234945297241
# /Users/macbookpro/Dropbox/Galvanize/autoregression/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
# 100%|██████████| 6/6 [00:37<00:00,  6.18s/it]
# PLOT RESIDUAL ERROR TIME: 0.19181180000305176
# GB: MSE = 0.07913604029217841
# PLOT BAR AND VIOLIN TIME: 1.7319729328155518
# (['RR', 'LASSO', 'DT', 'RF', 'GB', 'GB'],
#  [array([-0.06922269, -0.05374298, -0.07089901, -0.11045051, -0.12201605,
#          -0.14353475, -0.10857675, -0.06553661, -0.0647706 , -0.20096333]),
#   array([-0.07466373, -0.05449891, -0.06518851, -0.13789174, -0.11809095,
#          -0.14366524, -0.10407609, -0.08143108, -0.06681544, -0.17137648]),
#   array([-0.18666667, -0.14233333, -0.18733333, -0.21466667, -0.13866667,
#          -0.17333333, -0.17133333, -0.28133333, -0.09466667, -0.17666667]),
#   array([-0.07626667, -0.1118333 , -0.08596667, -0.13115593, -0.12312   ,
#          -0.15916   , -0.1579    , -0.11372667, -0.12925333, -0.07181333]),
#   array([-0.0609958 , -0.07027968, -0.08195396, -0.12403023, -0.15991791,
#          -0.16690153, -0.12979993, -0.17262011, -0.09487347, -0.11575913]),
#   array([-0.08525228, -0.07409369, -0.09473091, -0.15484697, -0.13208695,
#          -0.15197307, -0.12274909, -0.10734443, -0.12920226, -0.10847504])],
#  [RidgeCV(alphas=array([  1.00000e-02,   5.62341e-01,   3.16228e+01,   1.77828e+03,
#            1.00000e+05]),
#       cv=None, fit_intercept=True, gcv_mode=None, normalize=False,
#       scoring=None, store_cv_values=False),
#   LassoCV(alphas=array([  1.00000e-02,   5.62341e-01,   3.16228e+01,   1.77828e+03,
#            1.00000e+05]),
#       copy_X=True, cv=None, eps=0.001, fit_intercept=True, max_iter=1000,
#       n_alphas=100, n_jobs=1, normalize=False, positive=False,
#       precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#       verbose=False),
#   DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              presort=False, random_state=None, splitter='best'),
#   RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0, warm_start=False),
#   GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#                max_leaf_nodes=None, min_impurity_decrease=0.0,
#                min_impurity_split=None, min_samples_leaf=1,
#                min_samples_split=2, min_weight_fraction_leaf=0.0,
#                n_estimators=100, presort='auto', random_state=None,
#                subsample=1.0, verbose=0, warm_start=False),
#   AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#            n_estimators=50, random_state=None)],
#  <regression_tools.dftransformers.FeatureUnion at 0x122a81b00>)

# %%
autoregression.compare_predictions(iris,'species')
# Out:
# MAKE SUBSAMPLE TIME: 3.814697265625e-06
# CLEAN_DF TIME: 0.0058138370513916016
# PLOT CORRELATION TIME: 0.11092901229858398
#   0%|          | 0/8 [00:00<?, ?it/s]
# MAKE SCATTER TIME: 1.4586141109466553
#
# DF COLUMNS:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
#
# DF COLUMNS AFTER TRANSFORM:
# ['sepal_length_spline_linear', 'sepal_length_spline_0', 'sepal_length_spline_1', 'sepal_length_spline_2', 'sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species']
#
# 3
# Y VARIABLE: "species" IS CATEGORICAL
#
# LR: mean=0.953333 std=0.066999
# CV CALC TIME: 0.035108089447021484
# PLOT PREDICTED VS ACTUALS TIME: 2.1457672119140625e-06
# PLOT COEFFICIANTS TIME: 0.3356201648712158
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.269637107849121
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0033600330352783203
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     675         try:
# --> 676             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     677         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     203     if use_numexpr:
# --> 204         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     205     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x, y)
#      98                           default_axis=default_axis, reversed=True),
# ---> 99         rsub=arith_method(lambda x, y: y - x, names('rsub'), op('-'),
#     100                           default_axis=default_axis, reversed=True),
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#     699             with np.errstate(all='ignore'):
# --> 700                 return na_op(lvalues, rvalues)
#     701         except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     681                 mask = notna(x) & notna(y)
# --> 682                 result[mask] = op(x[mask], _values_from_object(y[mask]))
#     683             elif isinstance(x, np.ndarray):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x, y)
#      98                           default_axis=default_axis, reversed=True),
# ---> 99         rsub=arith_method(lambda x, y: y - x, names('rsub'), op('-'),
#     100                           default_axis=default_axis, reversed=True),
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-faaf6b0854cb> in <module>()
# ----> 1 autoregression.compare_predictions(iris,'species')
#
# ~/Dropbox/Galvanize/autoregression/autoregression/autoregression.py in compare_predictions(df, y_var_name, percent_data, category_limit, knots, bootstrap_coefs, partial_dep, actual_vs_predicted, residuals, univariates, bootstraps)
#     370
#     371         # get logloss later
# --> 372         print(f'{name}: MSE = {np.mean((y_hat-y)**2)}')
#     373
#     374     # --COMPARE MODELS--
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(left, right, name, na_op)
#     737                 lvalues = lvalues.values
#     738
# --> 739         result = wrap_results(safe_na_op(lvalues, rvalues))
#     740         return construct_result(
#     741             left,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#     708                 if is_object_dtype(lvalues):
#     709                     return libalgos.arrmap_object(lvalues,
# --> 710                                                   lambda x: op(x, rvalues))
#     711             raise
#     712
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x)
#     708                 if is_object_dtype(lvalues):
#     709                     return libalgos.arrmap_object(lvalues,
# --> 710                                                   lambda x: op(x, rvalues))
#     711             raise
#     712
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x, y)
#      97         rmul=arith_method(operator.mul, names('rmul'), op('*'),
#      98                           default_axis=default_axis, reversed=True),
# ---> 99         rsub=arith_method(lambda x, y: y - x, names('rsub'), op('-'),
#     100                           default_axis=default_axis, reversed=True),
#     101         rtruediv=arith_method(lambda x, y: operator.truediv(y, x),
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
