# %%
import autoregression
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
import numpy as np
iris['sepal_length'].dtype is np.dtype('float') or iris['sepal_length'].dtype is np.dtype('float') is np.dtype('int')
# Out:
# True

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
np.dtype(iris['sepal_length'])
# Out:
# dtype('float64')

# %%
iris.head(10)
iris.iloc[2,4] = np.inf
iris.head(10)
df_X = iris
cat_feature_name = 'species'
df_X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5      1.400000          0.2     setosa
# 1             4.9          3.0      1.400000          0.2     setosa
# 2             4.7          3.2           inf          0.2        inf
# 3             4.6          3.1      1.500000          0.2     setosa
# 4             5.0          3.6           inf          0.2     setosa
# 5             5.4          3.9      1.700000          0.4     setosa
# 6             4.6          3.4      1.400000          0.3     setosa
# 7             5.0          3.4      1.500000          0.2     setosa
# 8             4.4          2.9      1.400000          0.2     setosa
# 9             4.9          3.1      1.500000          0.1     setosa
# 10            5.4          3.7      1.500000          0.2     setosa
# 11            4.8          3.4      1.600000          0.2     setosa
# 12            4.8          3.0      1.400000          0.1     setosa
# ...

# %%
df_X.mask(df_X[cat_feature_name] == np.inf)[cat_feature_name]
# Out:
# 0         setosa
# 1         setosa
# 2            NaN
# 3         setosa
# 4         setosa
# 5         setosa
# 6         setosa
# 7         setosa
# 8         setosa
# 9         setosa
# 10        setosa
# 11        setosa
# 12        setosa
# 13        setosa
# 14        setosa
# 15        setosa
# 16        setosa
# 17        setosa
# 18        setosa
# 19        setosa
# 20        setosa
# 21        setosa
# 22        setosa
# 23        setosa
# 24        setosa
# 25        setosa
# 26        setosa
# 27        setosa
# 28        setosa
# 29        setosa
#          ...
# 120    virginica
# 121    virginica
# 122    virginica
# 123    virginica
# 124    virginica
# 125    virginica
# 126    virginica
# 127    virginica
# 128    virginica
# 129    virginica
# 130    virginica
# 131    virginica
# 132    virginica
# 133    virginica
# 134    virginica
# 135    virginica
# 136    virginica
# 137    virginica
# 138    virginica
# 139    virginica
# 140    virginica
# ...

# %%
autoregression.compare_predictions(iris,'species')
# Out:
# MAKE SUBSAMPLE TIME: 2.86102294921875e-06
# CLEAN_DF TIME: 0.0064699649810791016
# PLOT CORRELATION TIME: 0.13776206970214844
#   0%|          | 0/5 [00:00<?, ?it/s]
# MAKE SCATTER TIME: 1.493847131729126
#
# DF COLUMNS:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
#
# DF COLUMNS AFTER TRANSFORM:
# ['sepal_length_spline_linear', 'sepal_length_spline_0', 'sepal_length_spline_1', 'sepal_length_spline_2', 'sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species']
#
# 3
# Y VARIABLE: "species" IS CATEGORICAL
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
# ...

# %%
2 * '3'
