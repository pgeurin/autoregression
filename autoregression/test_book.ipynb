# %%
import autoregression
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
autoregression.compare_predictions(iris,'sepal length')
# Out:
# MAKE SUBSAMPLE TIME: 3.0994415283203125e-06
# CLEAN_DF TIME: 0.38968801498413086
# PLOT CORRELATION TIME: 0.1071171760559082
# MAKE SCATTER TIME: 1.4384310245513916
#
# DF COLUMNS:
# ['sepal_width', 'petal_length', 'petal_width', 'species', 'sepal_length']
#
# DF COLUMNS AFTER TRANSFORM:
# ['sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species_setosa_category', 'species_versicolor_category', 'species_virginica_category', 'sepal_length']
#
# 35
# Y VARIABLE: "sepal_length" IS CONTINUOUS
#
# ['sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species_setosa_category', 'species_versicolor_category', 'species_virginica_category', 'sepal_length']
# 13it [00:08,  1.61it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# RR: mean=-0.100971 std=0.043714
# CV CALC TIME: 0.03031301498413086
# PLOT PREDICTED VS ACTUALS TIME: 0.2847259044647217
# PLOT COEFFICIANTS TIME: 0.33961009979248047
# PLOT BOOTSTRAP COEFFICIANTS TIME: 3.064044952392578
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 1.5519988536834717
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-28462351380e> in <module>()
# ----> 1 autoregression.compare_predictions(iris,'sepal length')
#
# ~/Dropbox/Galvanize/autoregression/autoregression/autoregression.py in compare_predictions(df, y_var_name, percent_data, category_limit, knots, bootstrap_coefs, partial_dep, actual_vs_predicted, residuals, univariates, bootstraps)
#     329             start = time()
#     330             hot_categorical_vars = [column for column in df.columns if (len(df[column].unique()) == 2)]
# --> 331             galgraphs.shaped_plot_partial_dependences(model, df[[y_var_name]+hot_categorical_vars], y_var_name)
#     332             plt.show()
#     333             print(f'PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: {time() - start}')
#
# ~/Dropbox/Galvanize/autoregression/autoregression/galgraphs.py in shaped_plot_partial_dependences(model, df, y_var_name, pipeline, n_points, **kwargs)
#     428                                    pipeline=pipeline,
#     429                                    n_points=n_points,
# --> 430                                    **kwargs)
#     431             axs.flatten()[i].set_title("{}: Partial Dependence Plot {}".format(X_feature,
#     432                                                                   model.__class__.__name__))
#
# ~/Dropbox/Galvanize/regression-tools/regression_tools/plotting_tools.py in plot_partial_depenence(ax, model, X, var_name, y, pipeline, n_points, **kwargs)
#     201         y_hat = model.predict_proba(Xpd)[:, 1]
#     202     else:
# --> 203         y_hat = model.predict(Xpd)
#     204     ax.plot(x_plot, y_hat, **kwargs)
#     205
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in _decision_function(self, X)
#     239         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     240         return safe_sparse_dot(X, self.coef_.T,
# --> 241                                dense_output=True) + self.intercept_
#     242
#     243     def predict(self, X):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     138         return ret
#     139     else:
# --> 140         return np.dot(a, b)
#     141
#     142
#
# ValueError: shapes (250,3) and (15,) not aligned: 3 (dim 1) != 15 (dim 0)

# %%
2 * '3'
