# %%
import autoregression

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
autoregression.compare_predictions(iris, 'sepal length')
# Out:
# MAKE SUBSAMPLE TIME: 3.0994415283203125e-06
# CLEAN_DF TIME: 0.5863549709320068
# PLOT CORRELATION TIME: 1.5205481052398682
# MAKE SCATTER TIME: 1.698814868927002
#
# DF COLUMNS:
# ['sepal_width', 'petal_length', 'petal_width', 'species', 'sepal_length']
# 0it [00:00, ?it/s]
# DF COLUMNS AFTER TRANSFORM:
# ['sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species_setosa_category', 'species_versicolor_category', 'species_virginica_category', 'sepal_length']
#
# 35
# Y VARIABLE: "sepal_length" IS CONTINUOUS
#
# ['sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species_setosa_category', 'species_versicolor_category', 'species_virginica_category', 'sepal_length']
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# 13it [00:09,  1.38it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# RR: mean=-0.100971 std=0.043714
# CV CALC TIME: 0.10270905494689941
# PLOT PREDICTED VS ACTUALS TIME: 0.24001789093017578
# PLOT COEFFICIANTS TIME: 0.3702688217163086
# PLOT BOOTSTRAP COEFFICIANTS TIME: 3.395756244659424
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.123026132583618
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.002704143524169922
# PLOT PREDICTEDS_VS_ACTUALS TIME: 4.341003894805908
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  17%|█▋        | 1/6 [00:11<00:57, 11.43s/it]
# PLOT RESIDUAL ERROR TIME: 0.7682349681854248
# RR: MSE = 0.0898878397274629
# LASSO: mean=-0.101770 std=0.037576
# CV CALC TIME: 0.21668100357055664
# PLOT PREDICTED VS ACTUALS TIME: 0.2959277629852295
# PLOT COEFFICIANTS TIME: 0.4898686408996582
# PLOT BOOTSTRAP COEFFICIANTS TIME: 4.156125068664551
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.379271984100342
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.002804994583129883
# PLOT PREDICTEDS_VS_ACTUALS TIME: 3.971464157104492
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  33%|███▎      | 2/6 [00:23<00:46, 11.70s/it]
# PLOT RESIDUAL ERROR TIME: 0.23379993438720703
# LASSO: MSE = 0.09671718092914221
# DT: mean=-0.167183 std=0.052025
# CV CALC TIME: 0.1929149627685547
# PLOT PREDICTED VS ACTUALS TIME: 0.24991297721862793
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.0067150592803955
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0019392967224121094
# PLOT PREDICTEDS_VS_ACTUALS TIME: 3.7187628746032715
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  50%|█████     | 3/6 [00:29<00:29,  9.96s/it]
# PLOT RESIDUAL ERROR TIME: 0.27108001708984375
# DT: MSE = 0.11647466666666675
# RF: mean=-0.105181 std=0.023462
# CV CALC TIME: 0.28578615188598633
# PLOT PREDICTED VS ACTUALS TIME: 0.3223390579223633
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.465704917907715
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.002267122268676758
# PLOT PREDICTEDS_VS_ACTUALS TIME: 4.12582802772522
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  67%|██████▋   | 4/6 [00:37<00:18,  9.40s/it]
# PLOT RESIDUAL ERROR TIME: 0.1878206729888916
# RF: MSE = 0.05410411714285715
# GB: mean=-0.118545 std=0.038311
# CV CALC TIME: 0.627824068069458
# PLOT PREDICTED VS ACTUALS TIME: 0.3299117088317871
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.257838726043701
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.004010915756225586
# PLOT PREDICTEDS_VS_ACTUALS TIME: 3.9453389644622803
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  83%|████████▎ | 5/6 [00:45<00:09,  9.09s/it]
# PLOT RESIDUAL ERROR TIME: 0.2507939338684082
# GB: MSE = 0.05284771741222058
# GB: mean=-0.107589 std=0.028074
# CV CALC TIME: 1.1156878471374512
# PLOT PREDICTED VS ACTUALS TIME: 0.34626102447509766
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.5790278911590576
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.001500844955444336
# PLOT PREDICTEDS_VS_ACTUALS TIME: 3.3146920204162598
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
# 100%|██████████| 6/6 [00:54<00:00,  9.05s/it]
# PLOT RESIDUAL ERROR TIME: 0.2269299030303955
# GB: MSE = 0.09034102078875726
# PLOT BAR AND VIOLIN TIME: 2.684523820877075
# (['RR', 'LASSO', 'DT', 'RF', 'GB', 'GB'],
#  [array([-0.06922269, -0.05374298, -0.07089901, -0.11045051, -0.12201605,
#          -0.14353475, -0.10857675, -0.06553661, -0.0647706 , -0.20096333]),
#   array([-0.07466373, -0.05449891, -0.06518851, -0.13789174, -0.11809095,
#          -0.14366524, -0.10407609, -0.08143108, -0.06681544, -0.17137648]),
#   array([-0.09666667, -0.1625    , -0.138     , -0.19866667, -0.13666667,
#          -0.182     , -0.20333333, -0.28133333, -0.09866667, -0.174     ]),
#   array([-0.07324   , -0.09646667, -0.10086667, -0.13539377, -0.11348   ,
#          -0.13082427, -0.11903333, -0.09353852, -0.12760667, -0.06136   ]),
#   array([-0.06060653, -0.07249651, -0.0834774 , -0.12403023, -0.15906567,
#          -0.16814148, -0.12957818, -0.17545132, -0.09684645, -0.11575913]),
#   array([-0.08300819, -0.05464021, -0.08405169, -0.1283918 , -0.11334998,
#          -0.15304856, -0.13791689, -0.09491985, -0.12428815, -0.10227032])],
#  [RidgeCV(alphas=array([  1.00000e-02,   5.62341e-01,   3.16228e+01,   1.77828e+03,
#            1.00000e+05]),
#       cv=None, fit_intercept=True, gcv_mode=None, normalize=False,
#       scoring=None, store_cv_values=False),
#   LassoCV(alphas=array([  1.00000e-02,   5.62341e-01,   3.16228e+01,   1.77828e+03,
#            1.00000e+05]),
#       copy_X=True, cv=None, eps=0.001, fit_intercept=True, max_iter=1000,
#       n_alphas=100, n_jobs=1, normalize=False, positive=False,
#       precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#       verbose=False),
#   DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              presort=False, random_state=None, splitter='best'),
#   RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0, warm_start=False),
#   GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#                max_leaf_nodes=None, min_impurity_decrease=0.0,
#                min_impurity_split=None, min_samples_leaf=1,
#                min_samples_split=2, min_weight_fraction_leaf=0.0,
#                n_estimators=100, presort='auto', random_state=None,
#                subsample=1.0, verbose=0, warm_start=False),
#   AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#            n_estimators=50, random_state=None)],
#  <regression_tools.dftransformers.FeatureUnion at 0x11c8a5e10>)
