# %%
import autoregression

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
autoregression.compare_predictions(iris,'sepal length')
# Out:
# MAKE SUBSAMPLE TIME: 2.86102294921875e-06
# CLEAN_DF TIME: 0.28438711166381836
# PLOT CORRELATION TIME: 0.11652493476867676
# 0it [00:00, ?it/s]
# MAKE SCATTER TIME: 1.6529300212860107
#
# DF COLUMNS:
# ['sepal_width', 'petal_length', 'petal_width', 'species', 'sepal_length']
#
# DF COLUMNS AFTER TRANSFORM:
# ['sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species_setosa_category', 'species_versicolor_category', 'species_virginica_category', 'sepal_length']
#
# 35
# Y VARIABLE: "sepal_length" IS CONTINUOUS
#
# ['sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species_setosa_category', 'species_versicolor_category', 'species_virginica_category', 'sepal_length']
# 13it [00:09,  1.35it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# RR: mean=-0.100971 std=0.043714
# CV CALC TIME: 0.03250312805175781
# PLOT PREDICTED VS ACTUALS TIME: 0.23884797096252441
# PLOT COEFFICIANTS TIME: 0.34690380096435547
# PLOT BOOTSTRAP COEFFICIANTS TIME: 4.593228101730347
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.141129970550537
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0022139549255371094
# PLOT PREDICTEDS_VS_ACTUALS TIME: 3.5799989700317383
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  17%|█▋        | 1/6 [00:11<00:56, 11.21s/it]
# PLOT RESIDUAL ERROR TIME: 0.22961902618408203
# RR: MSE = 0.09565047514521374
# LASSO: mean=-0.101770 std=0.037576
# CV CALC TIME: 0.22103667259216309
# PLOT PREDICTED VS ACTUALS TIME: 0.3783862590789795
# PLOT COEFFICIANTS TIME: 0.46405625343322754
# PLOT BOOTSTRAP COEFFICIANTS TIME: 4.507362127304077
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.174826145172119
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0016651153564453125
# PLOT PREDICTEDS_VS_ACTUALS TIME: 3.4665019512176514
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  33%|███▎      | 2/6 [00:22<00:45, 11.44s/it]
# PLOT RESIDUAL ERROR TIME: 0.23543787002563477
# LASSO: MSE = 0.09098942243853496
# DT: mean=-0.174967 std=0.054650
# CV CALC TIME: 0.026314973831176758
# PLOT PREDICTED VS ACTUALS TIME: 0.28607702255249023
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.1859021186828613
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.004407167434692383
# PLOT PREDICTEDS_VS_ACTUALS TIME: 3.8203909397125244
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  50%|█████     | 3/6 [00:29<00:29,  9.84s/it]
# PLOT RESIDUAL ERROR TIME: 0.2834761142730713
# DT: MSE = 0.06784583333333336
# RF: mean=-0.125074 std=0.033473
# CV CALC TIME: 0.27601194381713867
# PLOT PREDICTED VS ACTUALS TIME: 0.40218400955200195
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.0898890495300293
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.0019598007202148438
# PLOT PREDICTEDS_VS_ACTUALS TIME: 4.076905012130737
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  67%|██████▋   | 4/6 [00:36<00:18,  9.25s/it]
# PLOT RESIDUAL ERROR TIME: 0.2728848457336426
# RF: MSE = 0.05120925962962963
# GB: mean=-0.117997 std=0.038680
# CV CALC TIME: 0.4463660717010498
# PLOT PREDICTED VS ACTUALS TIME: 0.36437511444091797
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.736783742904663
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.006506919860839844
# PLOT PREDICTEDS_VS_ACTUALS TIME: 5.015465974807739
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
#  83%|████████▎ | 5/6 [00:46<00:09,  9.26s/it]
# PLOT RESIDUAL ERROR TIME: 0.20298099517822266
# GB: MSE = 0.05378992240554321
# GB: mean=-0.113179 std=0.025021
# CV CALC TIME: 0.9447970390319824
# PLOT PREDICTED VS ACTUALS TIME: 0.40797901153564453
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT CONTINOUS PARTIAL DEPENDENCIES TIME: 2.6605780124664307
# PLOT CATEGORICAL PARTIAL DEPENDENCIES TIME: 0.002767801284790039
# PLOT PREDICTEDS_VS_ACTUALS TIME: 4.00040602684021
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/autoregression/autoregression.py:358: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   galgraphs.plot_residual_error(ax, df_X_sample.values[:,0].reshape(-1), y.reshape(-1), y_hat_sample.reshape(-1), s=30);
# 100%|██████████| 6/6 [00:55<00:00,  9.31s/it]
# PLOT RESIDUAL ERROR TIME: 0.21926212310791016
# GB: MSE = 0.07587171114018572
# PLOT BAR AND VIOLIN TIME: 2.3216068744659424
# (['RR', 'LASSO', 'DT', 'RF', 'GB', 'GB'],
#  [array([-0.06922269, -0.05374298, -0.07089901, -0.11045051, -0.12201605,
#          -0.14353475, -0.10857675, -0.06553661, -0.0647706 , -0.20096333]),
#   array([-0.07466373, -0.05449891, -0.06518851, -0.13789174, -0.11809095,
#          -0.14366524, -0.10407609, -0.08143108, -0.06681544, -0.17137648]),
#   array([-0.09666667, -0.15833333, -0.16066667, -0.25333333, -0.16266667,
#          -0.18066667, -0.17133333, -0.28133333, -0.10066667, -0.184     ]),
#   array([-0.12420667, -0.08791665, -0.07545   , -0.13606171, -0.15474667,
#          -0.16314   , -0.17188293, -0.14956667, -0.10320667, -0.08456   ]),
#   array([-0.06141655, -0.06990965, -0.0819732 , -0.1216504 , -0.16110606,
#          -0.17747435, -0.12979993, -0.16425187, -0.09662631, -0.11575913]),
#   array([-0.0781714 , -0.08351577, -0.08842789, -0.1446088 , -0.14270243,
#          -0.15223486, -0.11754993, -0.10557055, -0.11468076, -0.10432866])],
#  [RidgeCV(alphas=array([  1.00000e-02,   5.62341e-01,   3.16228e+01,   1.77828e+03,
#            1.00000e+05]),
#       cv=None, fit_intercept=True, gcv_mode=None, normalize=False,
#       scoring=None, store_cv_values=False),
#   LassoCV(alphas=array([  1.00000e-02,   5.62341e-01,   3.16228e+01,   1.77828e+03,
#            1.00000e+05]),
#       copy_X=True, cv=None, eps=0.001, fit_intercept=True, max_iter=1000,
#       n_alphas=100, n_jobs=1, normalize=False, positive=False,
#       precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#       verbose=False),
#   DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              presort=False, random_state=None, splitter='best'),
#   RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0, warm_start=False),
#   GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#                max_leaf_nodes=None, min_impurity_decrease=0.0,
#                min_impurity_split=None, min_samples_leaf=1,
#                min_samples_split=2, min_weight_fraction_leaf=0.0,
#                n_estimators=100, presort='auto', random_state=None,
#                subsample=1.0, verbose=0, warm_start=False),
#   AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#            n_estimators=50, random_state=None)],
#  <regression_tools.dftransformers.FeatureUnion at 0x113b3e2e8>)
