# %%
import autoregression

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
autoregression.compare_predictions(iris,'sepal_length')
# Out:
# Running: TAKE_SUBSAMPLE ...
# TAKE_SUBSAMPLE TIME: 7.152557373046875e-06
# Running: CLEAN_DF ...
# CLEAN_DF TIME: 0.183089017868042
# Running: MATSHOW ...
# MATSHOW TIME: 0.15810513496398926
# Running: PLOT_SCATTER_MATRIX ...
# PLOT_SCATTER_MATRIX TIME: 0.47066211700439453
# DF COLUMNS:
# ['sepal_width', 'petal_length', 'petal_width', 'species', 'sepal_length']
#
# DF COLUMNS AFTER TRANSFORM:
# ['sepal_width_spline_linear', 'sepal_width_spline_0', 'sepal_width_spline_1', 'sepal_width_spline_2', 'petal_length_spline_linear', 'petal_length_spline_0', 'petal_length_spline_1', 'petal_length_spline_2', 'petal_width_spline_linear', 'petal_width_spline_0', 'petal_width_spline_1', 'petal_width_spline_2', 'species_setosa_category', 'species_versicolor_category', 'species_virginica_category', 'sepal_length']
#
# 35
# Y VARIABLE: "sepal_length" IS CONTINUOUS
# 0it [00:00, ?it/s]/Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# 13it [00:08,  1.49it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running: CROSS_VAL_SCORE ...
# CROSS_VAL_SCORE TIME: 0.04325509071350098
# RR: mean=-0.100971 std=0.043714
# Running: PLOT_PREDICTED_VS_ACTUALS ...
# PLOT_PREDICTED_VS_ACTUALS TIME: 0.033812761306762695
# Running: PLOT_COEFS ...
# PLOT_COEFS TIME: 0.039270877838134766
# Running: PLOT_BOOTSTRAP_COEFS ...
# PLOT_BOOTSTRAP_COEFS TIME: 0.5098071098327637
# Running: PLOT_PARTIAL_DEPENDENCES ...
# /Users/macbookpro/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# PLOT_PARTIAL_DEPENDENCES TIME: 1.0573492050170898
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e45bff467ee3> in <module>()
# ----> 1 autoregression.compare_predictions(iris,'sepal_length')
#
# ~/Dropbox/Galvanize/autoregression/autoregression/autoregression.py in compare_predictions(df, y_var_name, percent_data, category_limit, knots, corr_matrix, scatter_matrix, bootstrap_coefs, feature_importances, partial_dep, actual_vs_predicted, residuals, univariates, compare_models, ROC, bootstraps)
#     372                                      sample_limit,
#     373                                      predicteds_vs_actuals=True,
# --> 374                                      residuals=True)
#     375
#     376         df_X = df.drop(y_var_name, axis=1)
#
# ~/Dropbox/Galvanize/autoregression/autoregression/galgraphs.py in plot_continuous_error_graphs(df, y, y_var_name, model, is_continuous, sample_limit, predicteds_vs_actuals, residuals)
#     550                 if predicteds_vs_actuals:
#     551                     (continuous_features, category_features) = sort_features(df_X_sample)
# --> 552                     timeit(plot_many_predicteds_vs_actuals, df_X_sample, continuous_features, y, y_hat_sample.reshape(-1), n_bins=50)
#     553                     plt.show()
#     554                     # plot_many_predicteds_vs_actuals(df_X_sample, category_features, y, y_hat_sample.reshape(-1), n_bins=50)
#
# NameError: name 'timeit' is not defined
